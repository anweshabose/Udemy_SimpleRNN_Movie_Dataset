# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
### sentences
sentences=[  'the glass of milk',
     'the glass of juice',
     'the cup of tea',
    'I am a good boy',
     'I am a good developer',
     'understand the meaning of words',
     'your videos are good',]
sentences
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
## Define the vocabulary size
voc_size=10000

# %% [markdown]
# # One Hot Representation

# %%
one_hot_repr=[one_hot(sentence,voc_size) for sentence in sentences]
one_hot_repr
# If we expand "The", it will be in 6258th index of the entire vector which is of dimention 10000.
# If we expand "good", it will be in 2035th index of the entire vector which is of dimention 10000.
# Out:
# [[6258, 7235, 6888, 8948],
#  [6258, 7235, 6888, 4278],
#  [6258, 6121, 6888, 9990],
#  [3642, 5135, 2555, 2035, 762],
#  [3642, 5135, 2555, 2035, 5248],
#  [8345, 6258, 2501, 6888, 7495],
#  [5207, 2906, 3251, 2035]]

# %% [markdown]
# # Word Embedding Representation

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential
import numpy as np

# %%
max_sent_length=8
embedded_docs=pad_sequences(one_hot_repr,padding='pre',maxlen=max_sent_length)
print(embedded_docs)
# all sentences are made of equal length using padding
# Out:
# [[   0    0    0    0 6258 7235 6888 8948]
#  [   0    0    0    0 6258 7235 6888 4278]
#  [   0    0    0    0 6258 6121 6888 9990]
#  [   0    0    0 3642 5135 2555 2035  762]
#  [   0    0    0 3642 5135 2555 2035 5248]
#  [   0    0    0 8345 6258 2501 6888 7495]
#  [   0    0    0    0 5207 2906 3251 2035]]

# %% [markdown]
# # Feature Representation

# %%
dim=10 # In Google, each word has 300 dimensions
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=max_sent_length)) # Embedding Layer
model.compile('adam','mse')
# Out:
# d:\Udemy\Complete_DSMLDLNLP_Bootcamp\Python\56-End to End DL Project with Simple RNN\venv\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# vector expansion of each word (sentence-wise) # vector dimension of each word is 10
# Each sentence have 8 words
# Total 7 sentences
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# array([[[ 4.45753969e-02, -4.62390184e-02,  4.01903279e-02,
#           9.56351683e-03,  2.02530064e-02,  1.81475542e-02,
#          -2.02062726e-02, -1.72649845e-02, -3.67956981e-02,
#           3.47147137e-03],
#         [ 4.45753969e-02, -4.62390184e-02,  4.01903279e-02,
#           9.56351683e-03,  2.02530064e-02,  1.81475542e-02,
#          -2.02062726e-02, -1.72649845e-02, -3.67956981e-02,
#           3.47147137e-03],
#         [ 4.45753969e-02, -4.62390184e-02,  4.01903279e-02,
#           9.56351683e-03,  2.02530064e-02,  1.81475542e-02,
#          -2.02062726e-02, -1.72649845e-02, -3.67956981e-02,
#           3.47147137e-03],
#         [ 4.45753969e-02, -4.62390184e-02,  4.01903279e-02,
#           9.56351683e-03,  2.02530064e-02,  1.81475542e-02,
#          -2.02062726e-02, -1.72649845e-02, -3.67956981e-02,
#           3.47147137e-03],
#         [-1.93661097e-02, -3.08101308e-02, -2.80199777e-02,
#          -2.40601599e-04, -3.05439159e-03, -1.42577663e-02,
#           4.02289666e-02,  1.11238845e-02,  1.42800100e-02,
#          -3.55543606e-02],
#         [-4.02978659e-02, -1.16333589e-02,  2.16586851e-02,
#          -1.21135488e-02,  3.97980101e-02,  3.44901718e-02,
#           4.48974632e-02, -5.23930788e-03, -4.12921533e-02,
#           1.68512948e-02],
#         [ 1.08383186e-02,  1.04135163e-02, -4.40970771e-02,
#           1.71039589e-02, -1.22136101e-02, -1.97067615e-02,
#          -8.51526856e-05, -9.71060991e-03,  4.49353792e-02,
#          -1.48788691e-02],
#         [ 2.58970521e-02, -3.93937007e-02,  3.66856568e-02,
#          -5.89537621e-03, -3.10659539e-02,  4.28838022e-02,
#           4.69351523e-02, -3.55267525e-02, -4.04346101e-02,
#          -2.99378987e-02]],
#
#        [[ 4.45753969e-02, -4.62390184e-02,  4.01903279e-02,
#           9.56351683e-03,  2.02530064e-02,  1.81475542e-02,
#          -2.02062726e-02, -1.72649845e-02, -3.67956981e-02,
#           3.47147137e-03],
#         [ 4.45753969e-02, -4.62390184e-02,  4.01903279e-02,
#           9.56351683e-03,  2.02530064e-02,  1.81475542e-02,
#          -2.02062726e-02, -1.72649845e-02, -3.67956981e-02,
#           3.47147137e-03],
#         [ 4.45753969e-02, -4.62390184e-02,  4.01903279e-02,
#           9.56351683e-03,  2.02530064e-02,  1.81475542e-02,
#          -2.02062726e-02, -1.72649845e-02, -3.67956981e-02,
#           3.47147137e-03],
#         [ 4.45753969e-02, -4.62390184e-02,  4.01903279e-02,
#           9.56351683e-03,  2.02530064e-02,  1.81475542e-02,
#          -2.02062726e-02, -1.72649845e-02, -3.67956981e-02,
#           3.47147137e-03],
#         [-1.93661097e-02, -3.08101308e-02, -2.80199777e-02,
#          -2.40601599e-04, -3.05439159e-03, -1.42577663e-02,
#           4.02289666e-02,  1.11238845e-02,  1.42800100e-02,
#          -3.55543606e-02],
#         [-4.02978659e-02, -1.16333589e-02,  2.16586851e-02,
#          -1.21135488e-02,  3.97980101e-02,  3.44901718e-02,
#           4.48974632e-02, -5.23930788e-03, -4.12921533e-02,
#           1.68512948e-02],
#         [ 1.08383186e-02,  1.04135163e-02, -4.40970771e-02,
#           1.71039589e-02, -1.22136101e-02, -1.97067615e-02,
#          -8.51526856e-05, -9.71060991e-03,  4.49353792e-02,
#          -1.48788691e-02],
#         [-1.49745457e-02,  4.67207693e-02,  3.83966081e-02,
#           4.70856689e-02, -4.15360928e-03, -2.91921739e-02,
#          -3.86337750e-02, -3.82812396e-02, -1.41320340e-02,
#          -4.85814698e-02]],
#
#        [[ 4.45753969e-02, -4.62390184e-02,  4.01903279e-02,
#           9.56351683e-03,  2.02530064e-02,  1.81475542e-02,
#          -2.02062726e-02, -1.72649845e-02, -3.67956981e-02,
#           3.47147137e-03],
#         [ 4.45753969e-02, -4.62390184e-02,  4.01903279e-02,
#           9.56351683e-03,  2.02530064e-02,  1.81475542e-02,
#          -2.02062726e-02, -1.72649845e-02, -3.67956981e-02,
#           3.47147137e-03],
#         [ 4.45753969e-02, -4.62390184e-02,  4.01903279e-02,
#           9.56351683e-03,  2.02530064e-02,  1.81475542e-02,
#          -2.02062726e-02, -1.72649845e-02, -3.67956981e-02,
#           3.47147137e-03],
#         [ 4.45753969e-02, -4.62390184e-02,  4.01903279e-02,
#           9.56351683e-03,  2.02530064e-02,  1.81475542e-02,
#          -2.02062726e-02, -1.72649845e-02, -3.67956981e-02,
#           3.47147137e-03],
#         
 4.45753969e-02, -4.62390184e-02,  4.01903279e-02,
#           9.56351683e-03,  2.02530064e-02,  1.81475542e-02,
#          -2.02062726e-02, -1.72649845e-02, -3.67956981e-02,
#           3.47147137e-03],
#         [ 4.45753969e-02, -4.62390184e-02,  4.01903279e-02,
#           9.56351683e-03,  2.02530064e-02,  1.81475542e-02,
#          -2.02062726e-02, -1.72649845e-02, -3.67956981e-02,
#           3.47147137e-03],
#         [ 4.45753969e-02, -4.62390184e-02,  4.01903279e-02,
#           9.56351683e-03,  2.02530064e-02,  1.81475542e-02,
#          -2.02062726e-02, -1.72649845e-02, -3.67956981e-02,
#           3.47147137e-03],
#         [ 2.21248306e-02,  3.59066464e-02, -4.03748862e-02,
#           4.38774563e-02,  1.47732385e-02, -3.47919576e-02,
#          -4.40071598e-02,  4.78969924e-02,  4.89132442e-02,
#          -2.44713947e-03],
#         [-1.93661097e-02, -3.08101308e-02, -2.80199777e-02,
#          -2.40601599e-04, -3.05439159e-03, -1.42577663e-02,
#           4.02289666e-02,  1.11238845e-02,  1.42800100e-02,
#          -3.55543606e-02],
#         [ 2.39901803e-02, -2.33902335e-02, -4.85599153e-02,
#           1.01777203e-02, -1.33215301e-02, -3.30727585e-02,
#          -1.11697540e-02,  2.50896104e-02, -1.20341890e-02,
#          -2.17431542e-02],
#         [ 1.08383186e-02,  1.04135163e-02, -4.40970771e-02,
#           1.71039589e-02, -1.22136101e-02, -1.97067615e-02,
#          -8.51526856e-05, -9.71060991e-03,  4.49353792e-02,
#          -1.48788691e-02],
#         [ 3.54364179e-02, -9.76836681e-03, -2.00072881e-02,
#           2.41661705e-02,  2.56034024e-02,  3.28421630e-02,
#          -1.36533603e-02,  2.23307684e-03, -4.91449125e-02,
#           4.04287614e-02]],
#
#        [[ 4.45753969e-02, -4.62390184e-02,  4.01903279e-02,
#           9.56351683e-03,  2.02530064e-02,  1.81475542e-02,
#          -2.02062726e-02, -1.72649845e-02, -3.67956981e-02,
#           3.47147137e-03],
#         [ 4.45753969e-02, -4.62390184e-02,  4.01903279e-02,
#           9.56351683e-03,  2.02530064e-02,  1.81475542e-02,
#          -2.02062726e-02, -1.72649845e-02, -3.67956981e-02,
#           3.47147137e-03],
#         [ 4.45753969e-02, -4.62390184e-02,  4.01903279e-02,
#           9.56351683e-03,  2.02530064e-02,  1.81475542e-02,
#          -2.02062726e-02, -1.72649845e-02, -3.67956981e-02,
#           3.47147137e-03],
#         [ 4.45753969e-02, -4.62390184e-02,  4.01903279e-02,
#           9.56351683e-03,  2.02530064e-02,  1.81475542e-02,
#          -2.02062726e-02, -1.72649845e-02, -3.67956981e-02,
#           3.47147137e-03],
#         [-7.36929104e-03, -2.26304531e-02,  3.87410633e-02,
#           4.54629548e-02, -3.22603583e-02,  2.66219042e-02,
#          -7.62986019e-03,  4.86036390e-03,  4.58521731e-02,
#          -1.51756518e-02],
#         [-4.86995094e-02,  3.48491184e-02, -4.25470136e-02,
#          -2.40256786e-02,  4.18034680e-02, -3.48624364e-02,
#          -2.71406528e-02, -3.32719460e-02, -4.07883152e-02,
#           2.64768042e-02],
#         [ 2.91766860e-02, -4.01748642e-02, -4.76949103e-02,
#           2.58653276e-02, -1.87518839e-02,  3.77420820e-02,
#           4.12332080e-02, -8.11228901e-03, -1.23175234e-03,
#           4.58411314e-02],
#         [-2.78197061e-02,  1.43162496e-02,  3.67579795e-02,
#           1.48148797e-02,  1.25905760e-02,  7.66895711e-04,
#          -2.12610718e-02,  4.73786034e-02, -2.93486360e-02,
#          -1.13892779e-02]]], dtype=float32)

# %%
embedded_docs[0] # 1st sentence
# Out:
# array([   0,    0,    0,    0, 6258, 7235, 6888, 8948])

# %%
# model.predict(embedded_docs[0])
model.predict(np.expand_dims(embedded_docs[0], axis=0)) # vector expansion of each word in the 1st sentence
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# array([[[ 4.45753969e-02, -4.62390184e-02,  4.01903279e-02,
#           9.56351683e-03,  2.02530064e-02,  1.81475542e-02,
#          -2.02062726e-02, -1.72649845e-02, -3.67956981e-02,
#           3.47147137e-03],
#         [ 4.45753969e-02, -4.62390184e-02,  4.01903279e-02,
#           9.56351683e-03,  2.02530064e-02,  1.81475542e-02,
#          -2.02062726e-02, -1.72649845e-02, -3.67956981e-02,
#           3.47147137e-03],
#         [ 4.45753969e-02, -4.62390184e-02,  4.01903279e-02,
#           9.56351683e-03,  2.02530064e-02,  1.81475542e-02,
#          -2.02062726e-02, -1.72649845e-02, -3.67956981e-02,
#           3.47147137e-03],
#         [ 4.45753969e-02, -4.62390184e-02,  4.01903279e-02,
#           9.56351683e-03,  2.02530064e-02,  1.81475542e-02,
#          -2.02062726e-02, -1.72649845e-02, -3.67956981e-02,
#           3.47147137e-03],
#         [-1.93661097e-02, -3.08101308e-02, -2.80199777e-02,
#          -2.40601599e-04, -3.05439159e-03, -1.42577663e-02,
#           4.02289666e-02,  1.11238845e-02,  1.42800100e-02,
#          -3.55543606e-02],
#         [-4.02978659e-02, -1.16333589e-02,  2.16586851e-02,
#          -1.21135488e-02,  3.97980101e-02,  3.44901718e-02,
#           4.48974632e-02, -5.23930788e-03, -4.12921533e-02,
#           1.68512948e-02],
#         [ 1.08383186e-02,  1.04135163e-02, -4.40970771e-02,
#           1.71039589e-02, -1.22136101e-02, -1.97067615e-02,
#          -8.51526856e-05, -9.71060991e-03,  4.49353792e-02,
#          -1.48788691e-02],
#         [ 2.58970521e-02, -3.93937007e-02,  3.66856568e-02,
#          -5.89537621e-03, -3.10659539e-02,  4.28838022e-02,
#           4.69351523e-02, -3.55267525e-02, -4.04346101e-02,
#          -2.99378987e-02]]], dtype=float32)
